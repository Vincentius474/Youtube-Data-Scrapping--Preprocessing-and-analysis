# %%
import time 
from selenium import webdriver
from selenium.webdriver.edge.service import Service
from selenium.webdriver.edge.options import Options 
from bs4 import BeautifulSoup 
import xlsxwriter
import requests

# %%
# url of the channel whose data you want to fetch 
urls = [ 
    'https://www.youtube.com/c/MacGpodcast/videos'
]

# %%
# Creating the soup of the content extracted by the microsoftedge driver

times = 0
row = 0
t = []
v = []
d = []
extracted_content = []

# Specify the path to the Edge WebDriver
service = Service(executable_path='C:/Users/vince/Downloads/edgedriver_win64/msedgedriver.exe')

# Set up Edge options (optional, can be customized as needed)
options = Options()
options.add_argument("start-maximized")  # Example option to open Edge maximized

# Initialize the Edge WebDriver with the service and options
driver = webdriver.Edge(service=service, options=options)

for url in urls:
    times = 0  # Reset times for each URL
    driver.get('{}/videos?view=0&sort=p&flow=grid'.format(url))
    
    # Scroll 5 times to load more content
    while times < 5:
        time.sleep(10)
        driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
        times += 1

    try:
        content = driver.page_source.encode('utf-8').strip()
        soup = BeautifulSoup(content, 'html')
        # print(f'Extracted time : {times} content : {soup}')
        extracted_content.append(soup)
        # You can now parse `soup` for extracting the required data
    
    except Exception as e:
        print(f"Error processing {url}: {e}")

# Closing the driver
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 21
#      18 driver = webdriver.Edge(service=service, options=options)
#      20 # Extract data (e.g., channel name and subscriber count)
# ---> 21 channel_name = driver.find_element(By.CSS_SELECTOR, 'yt-formatted-string.ytd-channel-name').text
#      22 subscriber_count = driver.find_element(By.CSS_SELECTOR, '#subscriber-count').text
#      24 # Print extracted information
#
# NameError: name 'By' is not defined

# %%
extracted_content
# Out:
# <html dark="" darker-dark-theme="" darker-dark-theme-deprecate="" lang="en-GB" refresh="" style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" system-icons="" typography="" typography-spacing=""><head><script data-loaded="true" id="js-1065286052" nonce="" src="https://www.gstatic.com/cv/js/sender/v1/cast_sender.js"></script><script data-loaded="true" id="js-1124342058" nonce="" src="//static.doubleclick.net/instream/ad_status.js"></script><script data-original-src="/s/player/03dbdfab/player_ias.vflset/en_GB/miniplayer.js" nonce="" src="/s/player/03dbdfab/player_ias.vflset/en_GB/miniplayer.js"></script><script data-original-src="/s/player/03dbdfab/player_ias.vflset/en_GB/remote.js" nonce="" src="/s/player/03dbdfab/player_ias.vflset/en_GB/remote.js"></script><script data-original-src="/s/player/03dbdfab/player_ias.vflset/en_GB/offline.js" nonce="" src="/s/player/03dbdfab/player_ias.vflset/en_GB/offline.js"></script><script data-id="_gd" nonce="">window.WIZ_global_data = {"MU
# ...

# %%
index = 0

titles = extracted_content.find_all('a') 
print(titles)

# for i in extracted_content:
#     print(f'index {index} \n {i} \n')
#     index += 1
# Out:
# []

# %%
# # Extracting the title, duration, views as per their respective id or class and storing them in a separate list

# # Title 
# titles = soup.findAll('a', id='video-title') 
# t =[] 
# for i in titles: 
#     t.append(i.text) 
  
# # Views 
# views = soup.findAll('span', class_='style-scope ytd-grid-video-renderer') 
# v = [] 
# count = 0
# for i in range(len(views)): 
#     if i%2 == 0: 
#         v.append(views[i].text) 
#     else: 
#         continue
  
# # Duration 
# duration = soup.findAll( 
#     'span', class_='style-scope ytd-thumbnail-overlay-time-status-renderer') 
# d = [] 
# for i in duration: 
#     d.append(i.text) 

# Extracting the title, duration, views as per their respective id or class and storing them in a separate list

# # Title
# titles = soup.find_all('a', id='video-title-link')
# print(titles)
# t = [] 
# for i in titles:
#     # Find the nested <yt-formatted-string> and extract its text
#     title_element = i.find('yt-formatted-string', class_='style-scope ytd-rich-grid-media')
#     if title_element:
#         t.append(title_element.text.strip())  # Strip leading/trailing whitespaces from the title


# # Views
# views = soup.find_all('span', class_='inline-metadata-item style-scope ytd-video-meta-block')
# v = [] 
# count = 0
# for i in range(len(views)): 
#     if i % 2 == 0:  # This logic seems to work if the views are placed in every other element
#         v.append(views[i].text.strip())
#     else:
#         continue

# # Duration
# duration = soup.find_all('div', class_='style-scope ytd-thumbnail-overlay-time-status-renderer')
# d = [] 
# for i in duration:
#     d.append(i.text.strip())  # Strip leading/trailing whitespaces from the duration

# Optional: Check if lists are empty or not
if not t:
    print("No titles found!")
if not v:
    print("No views found!")
if not d:
    print("No durations found!")

# Print or further process the results
print("Titles:", t)
print("Views:", v)
print("Durations:", d)
# Out:
# No titles found!
# No views found!
# No durations found!
# Titles: []
# Views: []
# Durations: []

# %%
# Ready to create the excel file

workbook = xlsxwriter.Workbook('Output Files/MacG.xlsx') 
worksheet = workbook.add_worksheet() 
  
worksheet.write(0, 0, "Title") 
worksheet.write(0, 1, "Views") 
worksheet.write(0, 2, "Duration") 
  
row = 1
for title, view, dura in zip(t,v,d): 
    worksheet.write(row, 0, title) 
    worksheet.write(row, 1, view) 
    worksheet.write(row, 2, dura) 
    row += 1
  
workbook.close()
